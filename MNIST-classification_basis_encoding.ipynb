# %%
import pennylane as qml
import tensorflow as tf
import sklearn.datasets
from sklearn.datasets import fetch_openml

import numpy as np

from matplotlib import pyplot as plt

tf.keras.backend.set_floatx('float64')

# %% [markdown]
# ## Load and reduce the data
#
# Load the MNIST data and check number of training and test examples

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Rescale the images from [0,255] to the [0.0,1.0] range.
x_train, x_test = x_train[..., np.newaxis]/255.0, x_test[..., np.newaxis]/255.0  # add colour dimension

print("Number of original training examples:", len(x_train))
print("Number of original test examples:", len(x_test))
# Out:
# Number of original training examples: 60000
# Number of original test examples: 10000

# %% [markdown]
# Create a function to filter out only 0 and 1

# %%
def filter_01(x, y):
    keep = (y == 3) | (y == 6)
    x, y = x[keep], y[keep]
    y = y == 3
    return x,y

# %%
x_train, y_train = filter_01(x_train, y_train)
x_test, y_test = filter_01(x_test, y_test)

print("Number of filtered training examples:", len(x_train))
print("Number of filtered test examples:", len(x_test))
# Out:
# Number of filtered training examples: 12049
# Number of filtered test examples: 1968

# %% [markdown]
# Plot the original images

# %%
plt.imshow(x_train[0, :, :, 0], cmap='Greys')
ax = plt.gca()
ax.set_xticks([])
ax.set_yticks([])
plt.title("28x28 image of a 0", fontsize=20)
# save to file as pdf
plt.savefig('28x28_MNIST_0.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# Reduce images to 9x9

# %%
x_train_small = tf.image.resize(x_train, (9,9)).numpy()
x_test_small = tf.image.resize(x_test, (9,9)).numpy()

# %%
plt.imshow(x_train_small[0,:,:,0], vmin=0, vmax=1, cmap='Greys')
ax = plt.gca()
ax.set_xticks([])
ax.set_yticks([])
plt.title("9x9 image of a 0", fontsize=20)
# save to file as pdf
plt.savefig('9x9_MNIST_0.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %% [markdown]
# Further reduce images to 9x1

# %%
x_train_small = x_train_small[:,4,:,:].reshape((-1,9))  # take only central slices
x_test_small = x_test_small[:,4,:,:].reshape((-1,9))  # take only central slices

plt.imshow(x_train_small[0,:].reshape((1,-1)), vmin=0, vmax=1, cmap='Greys')
ax = plt.gca()
ax.set_xticks([])
ax.set_yticks([])
plt.title("9x1 image of a 0", fontsize=20)
# save to file as pdf
plt.savefig('9x1_MNIST_0.pdf', bbox_inches='tight', pad_inches=0)
plt.show()

# %%
flattened_images_train = x_train.reshape(x_train.shape[0], -1)
flattened_images_test = x_test.reshape(x_test.shape[0], -1)

# %% [markdown]
# ## Set up the Quantum Neural Network
#
# Create quantum circuit using pennylane qnode, then conver this to a Keras layer to make a Keras model

# %%
n_qubits = 9
n_layers = 1
dev = qml.device("default.qubit", wires=n_qubits)

@qml.qnode(dev, diff_method="adjoint")
def qnode(inputs, weights):

    for ii in range(n_qubits):
        qml.RY(np.pi * inputs[ii], wires=ii)

    for jj in range(n_layers):
        for ii in range(n_qubits-1):
            qml.RZ(weights[jj,2*ii,0], wires=0)
            qml.RY(weights[jj,2*ii,1], wires=0)
            qml.RZ(weights[jj,2*ii,2], wires=0)

            qml.RZ(weights[jj,2*ii+1,0], wires=ii+1)
            qml.RY(weights[jj,2*ii+1,1], wires=ii+1)
            qml.RZ(weights[jj,2*ii+1,2], wires=ii+1)

            #qml.U3(*list(weights[jj,2*ii,:]), wires=0)
            #qml.U3(*list(weights[jj,2*ii+1,:]), wires=ii+1)
            qml.CNOT(wires=[ii+1,0])
            
        qml.RZ(weights[jj,2*(n_qubits-1),0], wires=0)
        qml.RY(weights[jj,2*(n_qubits-1),1], wires=0)
        qml.RZ(weights[jj,2*(n_qubits-1),2], wires=0)

    return qml.expval(qml.PauliZ(0))

weight_shapes = {"weights": (n_layers, 2*(n_qubits-1)+1, 3) }


qlayer = qml.qnn.KerasLayer(qnode, weight_shapes, output_dim=1, name="quantumLayer")
inputs = tf.keras.Input(shape=(n_qubits,), name="inputs")
outputs = qlayer(inputs)
model = tf.keras.Model(inputs=inputs, outputs=outputs, name="QNN")

model.predict(x_train_small[0,:])
print(model.summary())
# Out:
# 1/1 [==============================] - 0s 130ms/step
# Model: "QNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 9)]               0
#
#  quantumLayer (KerasLayer)   (None, 1)                 51
#
# =================================================================
# Total params: 51
# Trainable params: 51
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
weights =np.random.normal(size=(1, 17, 3)) 
inputs = np.random.normal(size=(9,1)) 
fig, ax = qml.draw_mpl(qnode, decimals=2)(inputs,weights)
fig.show()
# Out:
# C:\Users\pedir\AppData\Local\Temp\ipykernel_18964\4006239461.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# Redefine the classification values to match the Hinge loss

# %%
y_train_hinge = 2.0*y_train-1.0
y_test_hinge = 2.0*y_test-1.0

# %% [markdown]
# Define the hinge accuracy

# %%
def hinge_accuracy(y_true, y_pred):
    y_true = tf.squeeze(y_true) > 0.0
    y_pred = tf.squeeze(y_pred) > 0.0
    result = tf.cast(y_true == y_pred, tf.float32)

    return tf.reduce_mean(result)

# %% [markdown]
# ## Compile and train the model
#
# Compile the model using the hinge loss and accuracy and the Adam optimiser

# %%
model.compile(
    loss=tf.keras.losses.Hinge(),
    optimizer=tf.keras.optimizers.Adam(),
    metrics=[hinge_accuracy])

# %%
print(model.summary())
# Out:
# Model: "QNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 9)]               0
#
#  quantumLayer (KerasLayer)   (None, 1)                 51
#
# =================================================================
# Total params: 51
# Trainable params: 51
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Train the model over 20 epochs

# %%
EPOCHS = 100
BATCH_SIZE = 32

NUM_EXAMPLES = 512 #x_train_small.shape[0]
print(NUM_EXAMPLES)

x_train_sub = x_train_small[:NUM_EXAMPLES,:]
y_train_hinge_sub = y_train_hinge[:NUM_EXAMPLES]

x_test_sub = x_test_small[:,:]
y_test_sub = y_test[:]

qnn_history_1layer = model.fit(
      x_train_sub, y_train_hinge_sub,
      batch_size=BATCH_SIZE,
      epochs=EPOCHS,
      verbose=1)#,
      #validation_data=(x_test_sub, y_test_sub))

qnn_results_1layer = model.evaluate(x_test_sub, y_test_sub)
# Out:
# 512
# Epoch 1/100
# 16/16 [==============================] - 70s 4s/step - loss: 1.0107 - hinge_accuracy: 0.4512
# Epoch 2/100
# 16/16 [==============================] - 72s 4s/step - loss: 1.0022 - hinge_accuracy: 0.4785
# Epoch 3/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.9935 - hinge_accuracy: 0.4922
# Epoch 4/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.9857 - hinge_accuracy: 0.5098
# Epoch 5/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.9767 - hinge_accuracy: 0.5352
# Epoch 6/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.9679 - hinge_accuracy: 0.5430
# Epoch 7/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.9581 - hinge_accuracy: 0.5488
# Epoch 8/100
# 16/16 [==============================] - 67s 4s/step - loss: 0.9474 - hinge_accuracy: 0.5605
# Epoch 9/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.9358 - hinge_accuracy: 0.5820
# Epoch 10/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.9227 - hinge_accuracy: 0.6035
# Epoch 11/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.9087 - hinge_accuracy: 0.6250
# Epoch 12/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.8941 - hinge_accuracy: 0.6328
# Epoch 13/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.8795 - hinge_accuracy: 0.6328
# Epoch 14/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.8637 - hinge_accuracy: 0.6445
# Epoch 15/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.8487 - hinge_accuracy: 0.6582
# Epoch 16/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.8340 - hinge_accuracy: 0.6543
# Epoch 17/100
# 16/16 [==============================] - 70s 4s/step - loss: 0.8193 - hinge_accuracy: 0.6602
# Epoch 18/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.8058 - hinge_accuracy: 0.6641
# Epoch 19/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.7924 - hinge_accuracy: 0.6699
# Epoch 20/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.7796 - hinge_accuracy: 0.6777
# Epoch 21/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.7680 - hinge_accuracy: 0.6816
# Epoch 22/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.7572 - hinge_accuracy: 0.6914
# Epoch 23/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.7465 - hinge_accuracy: 0.7012
# Epoch 24/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.7371 - hinge_accuracy: 0.7188
# Epoch 25/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.7284 - hinge_accuracy: 0.7266
# Epoch 26/100
# 16/16 [==============================] - 67s 4s/step - loss: 0.7208 - hinge_accuracy: 0.7324
# Epoch 27/100
# 16/16 [==============================] - 67s 4s/step - loss: 0.7129 - hinge_accuracy: 0.7383
# Epoch 28/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.7061 - hinge_accuracy: 0.7402
# Epoch 29/100
# 16/16 [==============================] - 67s 4s/step - loss: 0.6999 - hinge_accuracy: 0.7402
# Epoch 30/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6939 - hinge_accuracy: 0.7441
# Epoch 31/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6888 - hinge_accuracy: 0.7461
# Epoch 32/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6841 - hinge_accuracy: 0.7441
# Epoch 33/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6796 - hinge_accuracy: 0.7500
# Epoch 34/100
# 16/16 [==============================] - 71s 4s/step - loss: 0.6754 - hinge_accuracy: 0.7500
# Epoch 35/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6719 - hinge_accuracy: 0.7539
# Epoch 36/100
# 16/16 [==============================] - 73s 5s/step - loss: 0.6684 - hinge_accuracy: 0.7520
# Epoch 37/100
# 16/16 [==============================] - 70s 4s/step - loss: 0.6651 - hinge_accuracy: 0.7578
# Epoch 38/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6624 - hinge_accuracy: 0.7598
# Epoch 39/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6596 - hinge_accuracy: 0.7637
# Epoch 40/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6572 - hinge_accuracy: 0.7617
# Epoch 41/100
# 16/16 [==============================] - 70s 4s/step - loss: 0.6551 - hinge_accuracy: 0.7676
# Epoch 42/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6528 - hinge_accuracy: 0.7715
# Epoch 43/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6509 - hinge_accuracy: 0.7715
# Epoch 44/100
# 16/16 [==============================] - 67s 4s/step - loss: 0.6491 - hinge_accuracy: 0.7754
# Epoch 45/100
# 16/16 [==============================] - 66s 4s/step - loss: 0.6474 - hinge_accuracy: 0.7754
# Epoch 46/100
# 16/16 [==============================] - 72s 5s/step - loss: 0.6461 - hinge_accuracy: 0.7773
# Epoch 47/100
# 16/16 [==============================] - 67s 4s/step - loss: 0.6443 - hinge_accuracy: 0.7773
# Epoch 48/100
# 16/16 [==============================] - 71s 4s/step - loss: 0.6431 - hinge_accuracy: 0.7773
# Epoch 49/100
# 16/16 [==============================] - 70s 4s/step - loss: 0.6419 - hinge_accuracy: 0.7754
# Epoch 50/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6404 - hinge_accuracy: 0.7793
# Epoch 51/100
# 16/16 [==============================] - 67s 4s/step - loss: 0.6394 - hinge_accuracy: 0.7754
# Epoch 52/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6382 - hinge_accuracy: 0.7734
# Epoch 53/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6371 - hinge_accuracy: 0.7754
# Epoch 54/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6363 - hinge_accuracy: 0.7754
# Epoch 55/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6351 - hinge_accuracy: 0.7715
# Epoch 56/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6344 - hinge_accuracy: 0.7695
# Epoch 57/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6335 - hinge_accuracy: 0.7754
# Epoch 58/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6327 - hinge_accuracy: 0.7754
# Epoch 59/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6322 - hinge_accuracy: 0.7754
# Epoch 60/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6311 - hinge_accuracy: 0.7676
# Epoch 61/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6303 - hinge_accuracy: 0.7578
# Epoch 62/100
# 16/16 [==============================] - 70s 4s/step - loss: 0.6298 - hinge_accuracy: 0.7520
# Epoch 63/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6290 - hinge_accuracy: 0.7520
# Epoch 64/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6283 - hinge_accuracy: 0.7520
# Epoch 65/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6277 - hinge_accuracy: 0.7520
# Epoch 66/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6269 - hinge_accuracy: 0.7520
# Epoch 67/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6265 - hinge_accuracy: 0.7480
# Epoch 68/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6259 - hinge_accuracy: 0.7500
# Epoch 69/100
# 16/16 [==============================] - 70s 4s/step - loss: 0.6259 - hinge_accuracy: 0.7480
# Epoch 70/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6248 - hinge_accuracy: 0.7441
# Epoch 71/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6245 - hinge_accuracy: 0.7441
# Epoch 72/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6240 - hinge_accuracy: 0.7441
# Epoch 73/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6234 - hinge_accuracy: 0.7441
# Epoch 74/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6229 - hinge_accuracy: 0.7422
# Epoch 75/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6224 - hinge_accuracy: 0.7402
# Epoch 76/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6219 - hinge_accuracy: 0.7402
# Epoch 77/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6217 - hinge_accuracy: 0.7422
# Epoch 78/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6212 - hinge_accuracy: 0.7402
# Epoch 79/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6207 - hinge_accuracy: 0.7383
# Epoch 80/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6205 - hinge_accuracy: 0.7363
# Epoch 81/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6199 - hinge_accuracy: 0.7324
# Epoch 82/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6195 - hinge_accuracy: 0.7305
# Epoch 83/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6194 - hinge_accuracy: 0.7305
# Epoch 84/100
# 16/16 [==============================] - 70s 4s/step - loss: 0.6190 - hinge_accuracy: 0.7324
# Epoch 85/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6185 - hinge_accuracy: 0.7324
# Epoch 86/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6182 - hinge_accuracy: 0.7305
# Epoch 87/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6178 - hinge_accuracy: 0.7285
# Epoch 88/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6176 - hinge_accuracy: 0.7305
# Epoch 89/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6172 - hinge_accuracy: 0.7305
# Epoch 90/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6168 - hinge_accuracy: 0.7305
# Epoch 91/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6166 - hinge_accuracy: 0.7305
# Epoch 92/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6164 - hinge_accuracy: 0.7305
# Epoch 93/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6160 - hinge_accuracy: 0.7305
# Epoch 94/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6157 - hinge_accuracy: 0.7305
# Epoch 95/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6154 - hinge_accuracy: 0.7305
# Epoch 96/100
# 16/16 [==============================] - 70s 4s/step - loss: 0.6153 - hinge_accuracy: 0.7305
# Epoch 97/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6148 - hinge_accuracy: 0.7285
# Epoch 98/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6148 - hinge_accuracy: 0.7285
# Epoch 99/100
# 16/16 [==============================] - 68s 4s/step - loss: 0.6148 - hinge_accuracy: 0.7285
# Epoch 100/100
# 16/16 [==============================] - 69s 4s/step - loss: 0.6141 - hinge_accuracy: 0.7305
# 62/62 [==============================] - 101s 2s/step - loss: 0.6440 - hinge_accuracy: 0.7041

# %%
import os
import pickle
filename= "basis_100_1hl_adam_adjoint.pickle"
history_path = os.path.join('history', filename)
with open(history_path, 'wb') as f:
    pickle.dump(qnn_history_1layer.history, f, pickle.HIGHEST_PROTOCOL)

# %%
with open('history/basis_20_1hl_adam_adjoint.pickle', "rb") as file_pi:
    history = pickle.load(file_pi)

# %%
history
# Out:
# [0.6936664879394415, 0.7550403225806451]

# %%
import pickle

pickle.dump(model, open('basis_20_epochs_1_ansatz_adam_adjoint.pkl', 'wb'))
# Out:
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers\input_layer
# ......vars
# ...layers\keras_layer
# ......vars
# .........0
# ...metrics\mean
# ......vars
# .........0
# .........1
# ...metrics\mean_metric_wrapper
# ......vars
# .........0
# .........1
# ...optimizer
# ......vars
# .........0
# .........1
# .........2
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# config.json                                    2023-04-24 22:01:32         1537
# metadata.json                                  2023-04-24 22:01:32           64
# variables.h5                                   2023-04-24 22:01:32        16144

# %% [markdown]
# Create and train a 2 layer version of the QNN

# %%
n_qubits = 9
n_layers = 2
dev = qml.device("default.qubit", wires=n_qubits)

@qml.qnode(dev, diff_method="adjoint")
def qnode(inputs, weights):

    for ii in range(n_qubits):
        qml.RY(np.pi * inputs[ii], wires=ii)

    for jj in range(n_layers):
        for ii in range(n_qubits-1):
            qml.RZ(weights[jj,2*ii,0], wires=0)
            qml.RY(weights[jj,2*ii,1], wires=0)
            qml.RZ(weights[jj,2*ii,2], wires=0)

            qml.RZ(weights[jj,2*ii+1,0], wires=ii+1)
            qml.RY(weights[jj,2*ii+1,1], wires=ii+1)
            qml.RZ(weights[jj,2*ii+1,2], wires=ii+1)

            #qml.U3(*list(weights[jj,2*ii,:]), wires=0)
            #qml.U3(*list(weights[jj,2*ii+1,:]), wires=ii+1)
            qml.CNOT(wires=[ii+1,0])
            
        qml.RZ(weights[jj,2*(n_qubits-1),0], wires=0)
        qml.RY(weights[jj,2*(n_qubits-1),1], wires=0)
        qml.RZ(weights[jj,2*(n_qubits-1),2], wires=0)

    return qml.expval(qml.PauliZ(0))

weight_shapes = {"weights": (n_layers, 2*(n_qubits-1)+1, 3) }


qlayer = qml.qnn.KerasLayer(qnode, weight_shapes, output_dim=1, name="quantumLayer")
inputs = tf.keras.Input(shape=(n_qubits,), name="inputs")
outputs = qlayer(inputs)
model2 = tf.keras.Model(inputs=inputs, outputs=outputs, name="QNN")

model2.predict(x_train_small[0,:])
print(model2.summary())
# Out:
# 1/1 [==============================] - 0s 66ms/step
# Model: "QNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inputs (InputLayer)         [(None, 9)]               0
#
#  quantumLayer (KerasLayer)   (None, 1)                 102
#
# =================================================================
# Total params: 102
# Trainable params: 102
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
model2.compile(
    loss=tf.keras.losses.Hinge(),
    optimizer=tf.keras.optimizers.Adam(),
    metrics=[hinge_accuracy])

# %%
EPOCHS = 20
BATCH_SIZE = 32

NUM_EXAMPLES = 512 #x_train_small.shape[0]
print(NUM_EXAMPLES)

x_train_sub = x_train_small[:NUM_EXAMPLES,:]
y_train_hinge_sub = y_train_hinge[:NUM_EXAMPLES]

x_test_sub = x_test_small[:,:]
y_test_sub = y_test[:]

qnn_history_2layer = model2.fit(
      x_train_sub, y_train_hinge_sub,
      batch_size=BATCH_SIZE,
      epochs=EPOCHS,
      verbose=1)#,
      #validation_data=(x_test_sub, y_test_sub))

qnn_results_2layer = model2.evaluate(x_test_sub, y_test_sub)
# Out:
# 512
# Epoch 1/20
# 16/16 [==============================] - 71s 4s/step - loss: 1.2125 - hinge_accuracy: 0.4531
# Epoch 2/20
# 16/16 [==============================] - 74s 5s/step - loss: 1.1559 - hinge_accuracy: 0.4590
# Epoch 3/20
# 16/16 [==============================] - 75s 5s/step - loss: 1.0883 - hinge_accuracy: 0.4590
# Epoch 4/20
# 16/16 [==============================] - 73s 5s/step - loss: 1.0023 - hinge_accuracy: 0.4590
# Epoch 5/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.8942 - hinge_accuracy: 0.4863
# Epoch 6/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.7746 - hinge_accuracy: 0.8496
# Epoch 7/20
# 16/16 [==============================] - 71s 4s/step - loss: 0.6595 - hinge_accuracy: 0.9121
# Epoch 8/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.5628 - hinge_accuracy: 0.9375
# Epoch 9/20
# 16/16 [==============================] - 74s 5s/step - loss: 0.4933 - hinge_accuracy: 0.9473
# Epoch 10/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4468 - hinge_accuracy: 0.9512
# Epoch 11/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.4132 - hinge_accuracy: 0.9570
# Epoch 12/20
# 16/16 [==============================] - 73s 5s/step - loss: 0.3883 - hinge_accuracy: 0.9570
# Epoch 13/20
# 16/16 [==============================] - 72s 4s/step - loss: 0.3676 - hinge_accuracy: 0.9551
# Epoch 14/20
# 16/16 [==============================] - 72s 5s/step - loss: 0.3494 - hinge_accuracy: 0.9551
# Epoch 15/20
# 16/16 [==============================] - 70s 4s/step - loss: 0.3332 - hinge_accuracy: 0.9551
# Epoch 16/20
# 16/16 [==============================] - 70s 4s/step - loss: 0.3185 - hinge_accuracy: 0.9551
# Epoch 17/20
# 16/16 [==============================] - 70s 4s/step - loss: 0.3048 - hinge_accuracy: 0.9570
# Epoch 18/20
# 16/16 [==============================] - 70s 4s/step - loss: 0.2920 - hinge_accuracy: 0.9570
# Epoch 19/20
# 16/16 [==============================] - 70s 4s/step - loss: 0.2797 - hinge_accuracy: 0.9590
# Epoch 20/20
# 16/16 [==============================] - 70s 4s/step - loss: 0.2677 - hinge_accuracy: 0.9590
# 67/67 [==============================] - 111s 2s/step - loss: 0.2527 - hinge_accuracy: 0.9711

# %% [markdown]
# ## Plot the results!

# %%
# plot the hinge accuracy for the qnn history for both 1 and 2 layer on the same axes
plt.plot(np.arange(1,21), qnn_history_1layer.history["hinge_accuracy"], label="1 layer QNN")
plt.plot(np.arange(1,21), qnn_history_2layer.history["hinge_accuracy"], label="2 layer QNN")
plt.xlabel("Epoch")
plt.ylabel("Hinge Accuracy")
plt.legend()
# modify x_ticks to also include 20
plt.xticks(np.arange(0, 21, 2.5))
# save as pdf with tight layout and no padding
plt.savefig("qnn_hinge_accuracy.pdf", bbox_inches="tight", pad_inches=0)
plt.show()

# %%
# plot the hinge accuracy for the loss for both 1 and 2 layer on the same axes
plt.plot(np.arange(1,21), qnn_history_1layer.history["loss"], label="1 layer QNN")
plt.plot(np.arange(1,21), qnn_history_2layer.history["loss"], label="2 layer QNN")
plt.xlabel("Epoch")
plt.ylabel("Hinge Loss")
plt.legend()
# modify x_ticks to also include 20
plt.xticks(np.arange(0, 21, 2.5))
# save as pdf with tight layout and no padding
plt.savefig("qnn_hinge_loss.pdf", bbox_inches="tight", pad_inches=0)
plt.show()
